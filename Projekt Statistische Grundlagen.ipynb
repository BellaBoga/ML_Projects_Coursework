# %%
import pandas as pd

df = pd.read_csv("./sf_salaries.csv", low_memory = False)

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
high_paying_jobs = df[df["TotalPay"] > 50000]

# %%
low_paying_jobs = df[df["TotalPay"] < 1000]

# %%
low_paying_jobs
# Out:
#             Id            EmployeeName  \
# 35365    35366             YANKUI CHEN
# 35366    35367           EXXON DICHOSO
# 35367    35368        MARGARET ROBERTS
# 35368    35369             DERRICK JOE
# 35369    35370            MARK CARROLL
# 35370    35371            MARY BIANCHI
# 35371    35372             JULIE COHEN
# 35372    35373          BONNIE BERNARD
# 35373    35374             IVY ESTACIO
# 35374    35375           NILDA ALVERIO
# 35375    35376                 ANN KIM
# 35376    35377          LINDA JURCISEK
# 35377    35378          ROMULO COCADIZ
# 35378    35379             WAI MAN HUI
# 35379    35380            PETER COWNAN
# 35380    35381         ETHAN SUNIEWICK
# 35381    35382             RYAN BUSTOS
# 35382    35383         JEFFREY JACKSON
# 35383    35384          GREGORY HANSEN
# 35384    35385           SID PORTER JR
# 35385    35386            JOVAN WALKER
# 35386    35387     FRANCISCA DOMINGUEZ
# 35387    35388           JOSEPH BROZZO
# ...

# %%
high_paying_jobs.head()
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# 1  2011    NaN  San Francisco    NaN

# %%
high_paying_jobs["TotalPay"]
# Out:
# 0    567595.43
# 1    538909.28
# Name: TotalPay, dtype: float64

# %%
year_2011 = df[df["Year"] == 2011]
year_2011["TotalPay"].mean()
# Out:
# 71744.10387123664

# %%
year_2011 = df[df["Year"] == 2012]
year_2011["TotalPay"].mean()
# Out:
# 74113.26226513737

# %%
year_2011 = df[df["Year"] == 2013]
year_2011["TotalPay"].mean()
# Out:
# 77611.44314205405

# %%
df["TotalPay"].mean()
# Out:
# 74768.321971703

# %%
df["TotalPay"].median()
# Out:
# 71426.60999999999

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.hist(df["TotalPay"], bins=100)
plt.show()
